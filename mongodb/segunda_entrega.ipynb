# %% [markdown]
# # Mongo DB con Python
#
# ##### Inicialización de la base de datos
#
# Para importart los datos a nuestra base de datos MongoDB, vamos a crear un pequeño programa en python para importar desde el fichero _incidentes.csv_ que hemos visto en la entrega anterior.

# %%
#!/usr/bin/env python
import os
from pymongo import MongoClient
import pandas as pd
import json
import progressbar

STEP = 200

client = MongoClient()
db = client['datascience']
incid = db.incidents
incid.delete_many({})
csv = pd.read_csv('/home/guillermo/data-science/cpp_db/incidents.csv', sep=';')

bar = progressbar.ProgressBar()
for start in bar(range(0, len(csv.index), STEP)):
    partial_csv = csv.loc[start:(start + STEP), :]
    csv_to_json = json.loads(partial_csv.to_json(orient='records'))
    incid.insert_many(csv_to_json)
    del partial_csv
    del csv_to_json
# Out:
# 100% |########################################################################|

# %% [markdown]
# Con esto, ya podemos hacer operaciones con los datos. En esta entrega nos centraremos en las consultas que podemos ver en el archivo README.md del proyecto.
#
# #### Preparar las consultas
#
# Para empezar a hacer consultas en PyMongo, primero tenemos que importar los paquetes necesarios, inicializar las variables de gráficas y conectar la base de datos a python:

# %%
import pandas as pd
import sys
sys.path.insert(0,'..')
import pymongo
from pymongo import MongoClient
from py2neo import Graph, authenticate
import matplotlib.pyplot as plt

graph = Graph()
print('Mongo version', pymongo.__version__)
client = MongoClient('localhost', 27017)
db = client.datascience
collection = db.incidents
# Out:
# Mongo version 3.6.1

# %% [markdown]
# Con esto, ya estamos conectados y listos para hacer consultas.
#
# ####  Distritos con mayor número de incidencias
#
# Para esta consulta, lo que tenemos que conseguir son las incidencias agrupadas por distritos.

# %%
incid_by_district = [
    {"$group": {"_id": "$PdDistrict", "count": {"$sum": 1}}}
]
aggResult = collection.aggregate(incid_by_district, allowDiskUse= True)
dist_count = pd.DataFrame(list(aggResult))
print("Distritos encontrados: ", dist_count["_id"].size)
dist_count
# Out:
# Distritos encontrados:  11
#            _id   count
# 0     RICHMOND  115715
# 1      TARAVAL  165447
# 2     NORTHERN  270115
# 3            0       1
# 4         PARK  124399
# 5      CENTRAL  223355
# 6    INGLESIDE  192696
# 7      MISSION  297224
# 8      BAYVIEW  219482
# 9   TENDERLOIN  190832
# 10    SOUTHERN  395889

# %% [markdown]
# En este caso vemos que hay una fila cuyo nombre es "0". Esto puede deberse a que el campo aparece como nulo o ha habido un error en la importación de los datos. Ahora mostraremos los distritos en una gráfica para poder analizarlos mejor.

# %%
days = dist_count['_id']
incidents = dist_count['count']

index = np.arange(dist_count["_id"].size)
plt.bar(index, incidents)
plt.xlabel('Day Of Week', fontsize=10)
plt.ylabel('nº of incidents', fontsize=7)
plt.xticks(index, days, fontsize=7, rotation=30)
plt.title('Incidents/Day of Week')
plt.show()

# %% [markdown]
# ####  Día de la semana con mayor número de incidentes
#
# En este caso, agruparemos los incidentes por día de la semana y los ordenaremos de mayor a menor. Los tres primeros serán aquellos en los que mas incidentes se produzcan.

# %%
day_incidences = [
    {"$group": {"_id": "$DayOfWeek", "count": {"$sum": 1}}},
    {"$sort": { "count": -1 }}
]
aggResult2 = collection.aggregate(day_incidences, allowDiskUse= True)
day_incid = pd.DataFrame(list(aggResult2))
print("Días de la semana: ", day_incid["_id"].size)
day_incid.head(3)
# Out:
# Días de la semana:  7
#          _id   count
# 0     Friday  334790
# 1  Wednesday  321096
# 2   Saturday  317543

# %% [markdown]
# Con esto concluimos que los días que más incidencias registran son los viernes, miércoles y sábados.
#
# #### Incidencias que impliquen la acción de un perro
#
# Estos incidentes tienen en común que aparece la palabra _DOG_ en su campo descripción. Para consultarlos, haremos uso de las expresiones regulares de MongoDB

# %%
incid_dogs = [
  {"$match": {"Descript": {"$regex": ".*DOG.*"}}}
]
aggResult3 = collection.aggregate(incid_dogs)
dog_no_res = pd.DataFrame(list(aggResult3))
print("Incidentes causados por perros: ", dog_no_res["_id"].size)
dog_no_res
# Out:
# Incidentes causados por perros:  3691
#                                          Address        Category        Date  \
# 0                        1000 Block of FOLSOM ST    NON-CRIMINAL  2015-02-01
# 1                        700 Block of STANYAN ST    NON-CRIMINAL  2015-02-06
# 2                      300 Block of EDINBURGH ST    NON-CRIMINAL  2015-01-28
# 3                        100 Block of TARAVAL ST    NON-CRIMINAL  2015-02-09
# 4                         0 Block of BROADWAY ST    NON-CRIMINAL  2015-02-12
# 5                          1300 Block of 28TH AV    NON-CRIMINAL  2015-02-15
# 6     BOWLINGGREEN DR / MARTIN LUTHER KING JR DR    NON-CRIMINAL  2015-02-16
# 7                       18TH ST / COLLINGWOOD ST    NON-CRIMINAL  2015-02-18
# 8                      CUMBERLAND ST / CHURCH ST    NON-CRIMINAL  2015-02-09
# 9                           0 Block of WALTER ST    NON-CRIMINAL  2015-02-18
# 10                         2200 Block of PINE ST    NON-CRIMINAL  2015-02-19
# 11                         1000 Block of EDDY ST    NON-CRIMINAL  2015-02-20
# 12                      200 Block of HOLLADAY AV    NON-CRIMINAL  2015-02-22
# 13                          16TH ST / POTRERO AV    NON-CRIMINAL  2015-02-23
# 14                       0 Block of WESTBROOK CT    NON-CRIMINAL  2015-02-08
# 15                          MISSION ST / 16TH ST    NON-CRIMINAL  2015-02-27
# 16                         OCTAVIA ST / HAYES ST    NON-CRIMINAL  2015-02-27
# 17                      1700 Block of NEWCOMB AV    NON-CRIMINAL  2015-01-03
# 18                    SANBENITO WY / MONTEREY BL    NON-CRIMINAL  2015-01-03
# 19                       LARKIN ST / OFARRELL ST    NON-CRIMINAL  2015-01-05
# 20                      600 Block of OFARRELL ST    NON-CRIMINAL  2015-01-07
# 21                  500 Block of JOHNFKENNEDY DR    NON-CRIMINAL  2015-01-08
# 22                        300 Block of MARKET ST    NON-CRIMINAL  2015-01-08
# 23                       500 Block of CLIPPER ST    NON-CRIMINAL  2015-01-04
# 24                    HUNTERSPOINT BL / HAWES ST    NON-CRIMINAL  2015-01-14
# 25                        100 Block of CRESPI DR    NON-CRIMINAL  2015-01-14
# 26                  500 Block of JOHNFKENNEDY DR    NON-CRIMINAL  2015-01-16
# 27                  100 Block of JOHNFSHELLEY DR    NON-CRIMINAL  2015-01-15
# 28                       GRIFFITH ST / THOMAS AV    NON-CRIMINAL  2015-01-19
# 29                         1700 Block of EDDY ST    NON-CRIMINAL  2015-01-21
# ...                                          ...             ...         ...
# 3661                  300 Block of MCALLISTER ST    NON-CRIMINAL  2017-08-17
# 3662                  300 Block of MCALLISTER ST    NON-CRIMINAL  2017-04-30
# 3663                  VANNESS AV / SACRAMENTO ST    NON-CRIMINAL  2017-04-30
# 3664                      600 Block of GIRARD ST    NON-CRIMINAL  2017-09-08
# 3665                      600 Block of GIRARD ST  OTHER OFFENSES  2017-09-08
# 3666                     200 Block of PEABODY ST    NON-CRIMINAL  2017-06-04
# 3667                     200 Block of LOMBARD ST    NON-CRIMINAL  2017-11-18
# 3668                     700 Block of MISSION ST    NON-CRIMINAL  2017-09-06
# 3669                       SILVER AV / REVERE AV    NON-CRIMINAL  2017-05-15
# 3670                        0 Block of BERTHA LN    NON-CRIMINAL  2017-09-15
# 3671                      DETROIT ST / JUDSON AV    NON-CRIMINAL  2017-09-15
# 3672                           0 Block of LEE AV    NON-CRIMINAL  2017-05-07
# 3673                         0 Block of ULLOA ST    NON-CRIMINAL  2017-07-31
# 3674                          EDDY ST / MASON ST    NON-CRIMINAL  2017-09-25
# 3675                        0 Block of BISHOP ST    NON-CRIMINAL  2017-10-27
# 3676                      800 Block of BRYANT ST    NON-CRIMINAL  2017-05-22
# 3677                        300 Block of POST ST    NON-CRIMINAL  2017-05-29
# 3678                    1400 Block of PORTOLA DR    NON-CRIMINAL  2017-02-04
# 3679                      100 Block of CHURCH ST    NON-CRIMINAL  2017-11-15
# 3680                       2000 Block of 47TH AV    NON-CRIMINAL  2017-10-15
# 3681                      400 Block of PERSIA AV    NON-CRIMINAL  2017-06-23
# 3682       1600 Block of THE EMBARCADERONORTH ST    NON-CRIMINAL  2017-06-30
# 3683                      UPPER TR / CLIFFORD TR    NON-CRIMINAL  2017-11-28
# 3684                    1500 Block of SHAFTER AV    NON-CRIMINAL  2017-04-11
# 3685                       300 Block of FAXON AV    NON-CRIMINAL  2017-05-26
# 3686                 300 Block of CHATTANOOGA ST    NON-CRIMINAL  2016-10-07
# 3687                     SEWARD ST / DOUGLASS ST    NON-CRIMINAL  2017-05-18
# 3688                        900 Block of COLE ST    NON-CRIMINAL  2017-05-18
# 3689                       300 Block of ELLIS ST    NON-CRIMINAL  2017-05-26
# 3690                     600 Block of NIAGARA AV    NON-CRIMINAL  2016-06-24
#
#       DayOfWeek               Descript  IncidntNum  \
# 0        Sunday   AIDED CASE, DOG BITE   150098630
# 1        Friday   AIDED CASE, DOG BITE   150113539
# 2     Wednesday   AIDED CASE, DOG BITE   150122295
# 3        Monday   AIDED CASE, DOG BITE   150123817
# 4      Thursday   AIDED CASE, DOG BITE   150132153
# 5        Sunday   AIDED CASE, DOG BITE   150141154
# 6        Monday   AIDED CASE, DOG BITE   150143984
# 7     Wednesday   AIDED CASE, DOG BITE   150150939
# 8        Monday   AIDED CASE, DOG BITE   150151200
# 9     Wednesday   AIDED CASE, DOG BITE   150151266
# 10     Thursday   AIDED CASE, DOG BITE   150153109
# 11       Friday   AIDED CASE, DOG BITE   150157311
# 12       Sunday   AIDED CASE, DOG BITE   150163142
# 13       Monday   AIDED CASE, DOG BITE   150166011
# 14       Sunday   AIDED CASE, DOG BITE   150170539
# 15       Friday   AIDED CASE, DOG BITE   150179569
# 16       Friday   AIDED CASE, DOG BITE   150181699
# 17     Saturday   AIDED CASE, DOG BITE   150007073
# 18     Saturday   AIDED CASE, DOG BITE   150010214
# 19       Monday   AIDED CASE, DOG BITE   150013575
# 20    Wednesday   AIDED CASE, DOG BITE   150021578
# 21     Thursday   AIDED CASE, DOG BITE   150022065
# 22     Thursday   AIDED CASE, DOG BITE   150027059
# 23       Sunday   AIDED CASE, DOG BITE   150029011
# 24    Wednesday   AIDED CASE, DOG BITE   150040562
# 25    Wednesday   AIDED CASE, DOG BITE   150041645
# 26       Friday   AIDED CASE, DOG BITE   150047358
# 27     Thursday   AIDED CASE, DOG BITE   150054626
# 28       Monday   AIDED CASE, DOG BITE   150056917
# 29    Wednesday   AIDED CASE, DOG BITE   150064926
# ...         ...                    ...         ...
# 3661   Thursday   AIDED CASE, DOG BITE   170670036
# 3662     Sunday   AIDED CASE, DOG BITE   170353129
# 3663     Sunday   AIDED CASE, DOG BITE   170353141
# 3664     Friday   AIDED CASE, DOG BITE   170735721
# 3665     Friday  DOG, STRAY OR VICIOUS   170735721
# 3666     Sunday   AIDED CASE, DOG BITE   170456303
# 3667   Saturday   AIDED CASE, DOG BITE   170939177
# 3668  Wednesday   AIDED CASE, DOG BITE   170728920
# 3669     Monday   AIDED CASE, DOG BITE   170399753
# 3670     Friday   AIDED CASE, DOG BITE   170755616
# 3671     Friday   AIDED CASE, DOG BITE   170755779
# 3672     Sunday   AIDED CASE, DOG BITE   170386108
# 3673     Monday   AIDED CASE, DOG BITE   170650652
# 3674     Monday   AIDED CASE, DOG BITE   170783833
# 3675     Friday   AIDED CASE, DOG BITE   170880081
# 3676     Monday   AIDED CASE, DOG BITE   170418949
# 3677     Monday   AIDED CASE, DOG BITE   170440384
# 3678   Saturday   AIDED CASE, DOG BITE   170099389
# 3679  Wednesday   AIDED CASE, DOG BITE   170930664
# 3680     Sunday   AIDED CASE, DOG BITE   170849275
# 3681     Friday   AIDED CASE, DOG BITE   170511979
# 3682     Friday   AIDED CASE, DOG BITE   170533810
# 3683    Tuesday   AIDED CASE, DOG BITE   170965100
# 3684    Tuesday   AIDED CASE, DOG BITE   170297486
# 3685     Friday   AIDED CASE, DOG BITE   170433210
# 3686     Friday   AIDED CASE, DOG BITE   160838426
# 3687   Thursday   AIDED CASE, DOG BITE   170408934
# 3688   Thursday   AIDED CASE, DOG BITE   170414204
# 3689     Friday   AIDED CASE, DOG BITE   170431496
# 3690     Friday   AIDED CASE, DOG BITE   160511177
#
#                                        Location  PdDistrict            PdId  \
# 0          (37.778254811523, -122.405834032593)    SOUTHERN  15009863064010
# 1         (37.7687142722405, -122.453376250788)        PARK  15011353964010
# 2         (37.7235205085999, -122.430194700261)   INGLESIDE  15012229564010
# 3          (37.743577781095, -122.466458192036)     TARAVAL  15012381764010
# 4          (37.798931272055, -122.398114598896)     CENTRAL  15013215364010
# 5         (37.7621853429495, -122.486772988151)     TARAVAL  15014115464010
# 6         (37.7674489968121, -122.460676556023)        PARK  15014398464010
# 7         (37.7608228396674, -122.436115302042)     MISSION  15015093964010
# 8         (37.7588908343024, -122.428127851577)     MISSION  15015120064010
# 9          (37.7683767091683, -122.43231121365)        PARK  15015126664010
# 10        (37.7880551073689, -122.433259737473)    NORTHERN  15015310964010
# 11         (37.7823192392643, -122.42577891406)    NORTHERN  15015731164010
# 12        (37.7457386010507, -122.405426113535)   INGLESIDE  15016314264010
# 13        (37.7657827544276, -122.407538332319)     MISSION  15016601164010
# 14        (37.7349303029099, -122.382452903681)     BAYVIEW  15017053964010
# 15        (37.7650501214668, -122.419671780296)     MISSION  15017956964010
# 16        (37.7766740025224, -122.424623480779)    NORTHERN  15018169964010
# 17        (37.7368743139473, -122.392563426886)     BAYVIEW  15000707364010
# 18        (37.7330918603016, -122.466998906716)     TARAVAL  15001021464010
# 19        (37.7851670875517, -122.417903977564)    NORTHERN  15001357564010
# 20        (37.7856087588303, -122.414850480524)  TENDERLOIN  15002157864010
# 21        (37.7725405391593, -122.466204667893)    RICHMOND  15002206564010
# 22        (37.7919805766981, -122.397742235773)    SOUTHERN  15002705964010
# 23        (37.7487495167115, -122.437185492674)     MISSION  15002901164010
# 24         (37.733618233775, -122.376974546817)     BAYVIEW  15004056264010
# 25        (37.7191006702792, -122.477129085936)     TARAVAL  15004164564010
# 26        (37.7725405391593, -122.466204667893)    RICHMOND  15004735864010
# 27        (37.7226694463003, -122.423304635548)   INGLESIDE  15005462664010
# 28        (37.7251087398496, -122.381940220312)     BAYVIEW  15005691764010
# 29         (37.7808493247624, -122.43644305449)        PARK  15006492664010
# ...                                         ...         ...             ...
# 3661    (37.78030898934026, -122.4177779326192)    NORTHERN  17067003664010
# 3662    (37.78030898934026, -122.4177779326192)    NORTHERN  17035312964010
# 3663    (37.7912889898479, -122.42251696661621)    NORTHERN  17035314164010
# 3664   (37.72438088867724, -122.40328290809276)     BAYVIEW  17073572164010
# 3665   (37.72438088867724, -122.40328290809276)     BAYVIEW  17073572164012
# 3666  (37.709004044312636, -122.40792248129415)   INGLESIDE  17045630364010
# 3667    (37.8037825925855, -122.40535579117254)     CENTRAL  17093917764010
# 3668  (37.785718469236905, -122.40284363862021)    SOUTHERN  17072892064010
# 3669  (37.736434147175956, -122.39855631822226)     BAYVIEW  17039975364010
# 3670  (37.733143500921194, -122.38099035655132)     BAYVIEW  17075561664010
# 3671  (37.728260804883355, -122.44427646378203)   INGLESIDE  17075577964010
# 3672   (37.71910631319513, -122.45401979569627)     TARAVAL  17038610864010
# 3673   (37.74517102769528, -122.45412850067837)        PARK  17065065264010
# 3674   (37.78434785131515, -122.40931311143102)  TENDERLOIN  17078383364010
# 3675   (37.71846903721544, -122.40432297558465)   INGLESIDE  17088008164010
# 3676     (37.775420706711, -122.40340479147905)    SOUTHERN  17041894964010
# 3677   (37.78844860197047, -122.40761288538702)     CENTRAL  17044038464010
# 3678   (37.73836534160335, -122.46732191041639)     TARAVAL  17009938964010
# 3679  (37.769061235353256, -122.42915988365783)    NORTHERN  17093066464010
# 3680   (37.74823257360059, -122.50622058746738)     TARAVAL  17084927564010
# 3681   (37.72137725615049, -122.43243363628996)   INGLESIDE  17051197964010
# 3682    (37.80843501758691, -122.4107742143754)     CENTRAL  17053381064010
# 3683  (37.763985326862915, -122.44441220016063)        PARK  17096510064010
# 3684  (37.730474150937354, -122.38984911479719)     BAYVIEW  17029748664010
# 3685   (37.72094542018786, -122.46015220894473)     TARAVAL  17043321064010
# 3686   (37.75135466941823, -122.42635998115628)     MISSION  16083842664010
# 3687  (37.757854179881924, -122.43907572115248)     MISSION  17040893464010
# 3688    (37.76533297677861, -122.4497937951308)        PARK  17041420464010
# 3689   (37.78502266227863, -122.41198764359528)  TENDERLOIN  17043149664010
# 3690   (37.72027091213869, -122.44973026030148)     TARAVAL  16051117764010
#
#           Resolution      Time           X          Y  \
# 0               NONE  18:38:00 -122.405834  37.778255
# 1               NONE  08:25:00 -122.453376  37.768714
# 2               NONE  18:30:00 -122.430195  37.723521
# 3               NONE  20:20:00 -122.466458  37.743578
# 4               NONE  13:30:00 -122.398115  37.798931
# 5     ARREST, BOOKED  16:45:00 -122.486773  37.762185
# 6               NONE  15:45:00 -122.460677  37.767449
# 7     ARREST, BOOKED  14:15:00 -122.436115  37.760823
# 8               NONE  17:58:00 -122.428128  37.758891
# 9     ARREST, BOOKED  16:59:00 -122.432311  37.768377
# 10              NONE  09:45:00 -122.433260  37.788055
# 11              NONE  18:28:00 -122.425779  37.782319
# 12    ARREST, BOOKED  13:04:00 -122.405426  37.745739
# 13              NONE  11:58:00 -122.407538  37.765783
# 14              NONE  15:40:00 -122.382453  37.734930
# 15    ARREST, BOOKED  10:13:00 -122.419672  37.765050
# 16              NONE  18:35:00 -122.424623  37.776674
# 17              NONE  12:37:00 -122.392563  37.736874
# 18              NONE  12:00:00 -122.466999  37.733092
# 19              NONE  12:45:00 -122.417904  37.785167
# 20    ARREST, BOOKED  23:55:00 -122.414850  37.785609
# 21              NONE  08:25:00 -122.466205  37.772541
# 22              NONE  19:00:00 -122.397742  37.791981
# 23              NONE  10:00:00 -122.437185  37.748750
# 24              NONE  08:43:00 -122.376975  37.733618
# 25              NONE  13:15:00 -122.477129  37.719101
# 26    ARREST, BOOKED  09:00:00 -122.466205  37.772541
# 27              NONE  17:00:00 -122.423305  37.722669
# 28              NONE  09:40:00 -122.381940  37.725109
# 29    ARREST, BOOKED  18:38:00 -122.436443  37.780849
# ...              ...       ...         ...        ...
# 3661  ARREST, BOOKED  12:45:00 -122.417778  37.780309
# 3662            NONE  09:00:00 -122.417778  37.780309
# 3663            NONE  08:45:00 -122.422517  37.791289
# 3664            NONE  21:45:00 -122.403283  37.724381
# 3665            NONE  21:45:00 -122.403283  37.724381
# 3666            NONE  09:10:00 -122.407922  37.709004
# 3667            NONE  11:39:00 -122.405356  37.803783
# 3668            NONE  19:15:00 -122.402844  37.785718
# 3669            NONE  18:20:00 -122.398556  37.736434
# 3670            NONE  20:50:00 -122.380990  37.733144
# 3671            NONE  17:35:00 -122.444276  37.728261
# 3672            NONE  13:45:00 -122.454020  37.719106
# 3673            NONE  16:00:00 -122.454129  37.745171
# 3674            NONE  17:44:00 -122.409313  37.784348
# 3675            NONE  17:30:00 -122.404323  37.718469
# 3676            NONE  10:00:00 -122.403405  37.775421
# 3677  ARREST, BOOKED  13:35:00 -122.407613  37.788449
# 3678  ARREST, BOOKED  14:35:00 -122.467322  37.738365
# 3679            NONE  10:30:00 -122.429160  37.769061
# 3680            NONE  12:00:00 -122.506221  37.748233
# 3681            NONE  13:30:00 -122.432434  37.721377
# 3682            NONE  18:00:00 -122.410774  37.808435
# 3683            NONE  10:50:00 -122.444412  37.763985
# 3684            NONE  18:19:00 -122.389849  37.730474
# 3685            NONE  18:00:00 -122.460152  37.720945
# 3686            NONE  13:30:00 -122.426360  37.751355
# 3687            NONE  16:17:00 -122.439076  37.757854
# 3688            NONE  15:00:00 -122.449794  37.765333
# 3689  ARREST, BOOKED  10:25:00 -122.411988  37.785023
# 3690  ARREST, BOOKED  09:00:00 -122.449730  37.720271
#
#                            _id
# 0     5adf345f183a4f700046816a
# 1     5adf345f183a4f700046881e
# 2     5adf345f183a4f7000468bf0
# 3     5adf345f183a4f7000468ca9
# 4     5adf345f183a4f7000469064
# 5     5adf345f183a4f700046944a
# 6     5adf345f183a4f7000469592
# 7     5adf345f183a4f70004698b0
# 8     5adf345f183a4f70004698ce
# 9     5adf345f183a4f70004698d5
# 10    5adf345f183a4f70004699ad
# 11    5adf345f183a4f7000469b89
# 12    5adf345f183a4f7000469e50
# 13    5adf345f183a4f7000469f99
# 14    5adf345f183a4f700046a1bc
# 15    5adf345f183a4f700046a5a3
# 16    5adf345f183a4f700046a69d
# 17    5adf345f183a4f700046a946
# 18    5adf345f183a4f700046aa94
# 19    5adf345f183a4f700046abda
# 20    5adf3460183a4f700046aed4
# 21    5adf3460183a4f700046af13
# 22    5adf3460183a4f700046b112
# 23    5adf3460183a4f700046b1fc
# 24    5adf3460183a4f700046b6f8
# 25    5adf3460183a4f700046b763
# 26    5adf3460183a4f700046b9c5
# 27    5adf3460183a4f700046bd1c
# 28    5adf3460183a4f700046be3e
# 29    5adf3460183a4f700046c1a9
# ...                        ...
# 3661  5adf34a0183a4f700067d563
# 3662  5adf34a0183a4f700067d9cc
# 3663  5adf34a0183a4f700067d9ce
# 3664  5adf34a0183a4f700067da3a
# 3665  5adf34a0183a4f700067da3b
# 3666  5adf34a0183a4f700067da4b
# 3667  5adf34a0183a4f700067db36
# 3668  5adf34a0183a4f700067dd67
# 3669  5adf34a0183a4f700067de92
# 3670  5adf34a0183a4f700067e11b
# 3671  5adf34a0183a4f700067e122
# 3672  5adf34a0183a4f700067e1d1
# 3673  5adf34a0183a4f700067e3f9
# 3674  5adf34a0183a4f700067e40a
# 3675  5adf34a0183a4f700067e4f8
# 3676  5adf34a0183a4f700067e621
# 3677  5adf34a0183a4f700067e63d
# 3678  5adf34a0183a4f700067e9ea
# 3679  5adf34a0183a4f700067eb9f
# 3680  5adf34a0183a4f700067ebb0
# 3681  5adf34a0183a4f700067ee63
# 3682  5adf34a0183a4f700067ee6a
# 3683  5adf34a0183a4f700067f4db
# 3684  5adf34a0183a4f700067f631
# 3685  5adf34a0183a4f700067f71b
# 3686  5adf34a0183a4f700067f7cd
# 3687  5adf34a0183a4f700067fa1a
# 3688  5adf34a0183a4f700067fa56
# 3689  5adf34a0183a4f700067fac3
# 3690  5adf34a0183a4f700067fee3
#
# [3691 rows x 14 columns]

# %% [markdown]
# #### Las 5 categorías más frecuentes.
#
# Al igual que en el caso de los días, agrupamos los incidentes por categoría y ordenamos de mayor a menor

# %%
common_categories = [
    {"$group": {"_id": "$Category", "count": {"$sum": 1}}},
    {"$sort": { "count": -1 }}
]
aggResult4 = collection.aggregate(common_categories)
comm_categ = pd.DataFrame(list(aggResult4))
print("Contador: ", comm_categ["_id"].size)
comm_categ.head(5)
# Out:
# Contador:  39
#               _id   count
# 0   LARCENY/THEFT  473931
# 1  OTHER OFFENSES  307251
# 2    NON-CRIMINAL  235977
# 3         ASSAULT  192645
# 4   VEHICLE THEFT  126273

# %% [markdown]
# #### Incidentes sin resolución
#
# Para ello, se necesita buscar aquellas incidencias que tengan un campo _Resolution_ con valor _NONE_.

# %%
no_resolution = [
  {"$match": {"Resolution": "NONE"}}
]
aggResult5 = collection.aggregate(no_resolution)
no_res = pd.DataFrame(list(aggResult5))
print("Incidentes sin resolver: ", no_res["_id"].size)
# Out:
# Incidentes sin resolver:  1373312
